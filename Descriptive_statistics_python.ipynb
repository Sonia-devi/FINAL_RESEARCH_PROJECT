# %% [markdown]
# <a href="https://colab.research.google.com/github/Sonia-devi/FINAL_RESEARCH_PROJECT/blob/main/Descriptive_statistics_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import scipy.stats as stats
from matplotlib import pyplot as plt
import seaborn as sns
from pandas import Series, DataFrame

# %%
#Load the Dataset
df = pd.read_excel(r"/content/transformation of dataset 1.xlsx")

# %%
df.head(10)
# Out:
#    Age Group  Handedness  Gender  Job Function  Weight  Height        BMI  \
# 0          1           1       0             1   102.0    1.84  30.127599
# 1          3           1       0             1    82.7    1.78  26.101502
# 2          1           1       0             1    80.0    2.00  20.000000
# 3          1           1       0             1    80.0    1.75  26.122449
# 4          0           1       0             1    89.0    1.78  28.089888
# 5          1           1       1             2    70.0    1.62  26.672763
# 6          3           1       0             1    89.0    1.73  29.737044
# 7          2           2       0             1    78.0    1.76  25.180785
# 8          2           1       0             1    65.0    1.80  20.061728
# 9          0           1       0             1    64.0    1.69  22.408179
#
#    Aviation Sector  Flight Hours  Flight Type  ...  Breathing Difficulties  \
# 0              1.0        5000.0          1.0  ...                       0
# ...

# %%
df.describe()
# Out:
#         Age Group  Handedness      Gender  Job Function      Weight  \
# count  295.000000  295.000000  295.000000    295.000000  291.000000
# mean     1.884746    0.894915    0.233898      2.423729   81.473952
# std      1.121954    0.394444    0.431975      1.812686   16.921862
# min      0.000000    0.000000    0.000000      1.000000   52.000000
# 25%      1.000000    1.000000    0.000000      1.000000   70.500000
# 50%      2.000000    1.000000    0.000000      1.000000   80.000000
# 75%      3.000000    1.000000    0.000000      4.000000   90.000000
# max      5.000000    2.000000    2.000000      6.000000  190.000000
#
#            Height         BMI  Aviation Sector  Flight Hours  Flight Type  \
# count  289.000000  287.000000       291.000000    166.000000   205.000000
# mean     1.763744   26.151228         1.439863   7755.638554     2.263415
# std      0.089251    4.893273         0.817265   5287.463592     1.248088
# ...

# %%
df.sample(frac=0.05)
# Out:
#      Age Group  Handedness  Gender  Job Function  Weight  Height        BMI  \
# 99           2           1       0             1    60.0    1.72  20.281233
# 17           2           1       0             1    91.0    1.73  30.405293
# 93           3           1       0             1   110.0    1.78  34.717839
# 8            2           1       0             1    65.0    1.80  20.061728
# 126          3           1       0             1   116.0    1.88  32.820281
# 238          2           1       1             3    74.0    1.60  28.906250
# 120          1           1       0             1    52.0    1.72  17.577069
# 216          3           1       1             4    58.0    1.65  21.303949
# 146          2           1       0             1    82.0     NaN        NaN
# 141          0           1       1             1     NaN     NaN        NaN
# 105          3           1       0             1    71.0    1.78  22.408787
# ...

# %%
sample_data = df.sample(frac=0.05)

# %%
sample_data.describe()
# Out:
#        Age Group  Handedness     Gender  Job Function      Weight     Height  \
# count  15.000000   15.000000  15.000000     15.000000   15.000000  15.000000
# mean    2.200000    0.800000   0.400000      2.733333   80.994667   1.744000
# std     0.941124    0.414039   0.507093      1.980861   16.903799   0.090063
# min     1.000000    0.000000   0.000000      1.000000   60.000000   1.640000
# 25%     1.500000    1.000000   0.000000      1.000000   70.500000   1.680000
# 50%     2.000000    1.000000   0.000000      2.000000   78.000000   1.750000
# 75%     3.000000    1.000000   1.000000      4.000000   87.500000   1.780000
# max     4.000000    1.000000   1.000000      6.000000  130.000000   2.000000
#
#              BMI  Aviation Sector  Flight Hours  Flight Type  ...  \
# count  14.000000        15.000000      7.000000     10.00000  ...
# mean   26.777798         1.533333   6848.571429      1.70000  ...
# std     3.197371         0.833809   5965.476870      1.05935  ...
# ...

# %%
# Calculate descriptive statistics for BMI
BMI_stats = df["BMI"].describe()
print("BMI descriptive statistics:",BMI_stats)
# Out:
# BMI descriptive statistics: count    287.000000
# mean      26.151228
# std        4.893273
# min       17.577069
# 25%       23.219689
# 50%       25.712199
# 75%       27.763900
# max       65.743945
# Name: BMI, dtype: float64

# %%
# Calculate descriptive statistics for Bad dreams
Bad_dreams_stats = df["Bad dreams"].describe()
print("Bad dreams descriptive statistics:", Bad_dreams_stats)
# Out:
# Bad dreams descriptive statistics: count    294.000000
# mean       0.649660
# std        0.975668
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        3.000000
# Name: Bad dreams, dtype: float64

# %%
# Calculate descriptive statistics for Job Function
Job_Function_stats = df["Job Function"].describe()
print("Job Function descriptive statistics:", Job_Function_stats)
# Out:
# Job Function descriptive statistics: count    295.000000
# mean       2.423729
# std        1.812686
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        4.000000
# max        6.000000
# Name: Job Function, dtype: float64

# %%
# Calculate descriptive statistics for Aviation Sector
Aviation_Sector_stats = df["Aviation Sector"].describe()
print("Aviation Sector descriptive statistics:", Aviation_Sector_stats)
# Out:
# Aviation Sector descriptive statistics: count    291.000000
# mean       1.439863
# std        0.817265
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        2.000000
# max        5.000000
# Name: Aviation Sector, dtype: float64

# %%
# Calculate descriptive statistics for Flight Hours
Flight_Hours_stats = df["Flight Hours"].describe()
print("Flight Hours descriptive statistics:", Flight_Hours_stats)
# Out:
# Flight Hours descriptive statistics: count      166.000000
# mean      7755.638554
# std       5287.463592
# min         56.000000
# 25%       3500.000000
# 50%       7020.000000
# 75%      11875.000000
# max      22000.000000
# Name: Flight Hours, dtype: float64

# %% [markdown]
# Hypothesis Testing
#
# Research Question : How sleep quailty
